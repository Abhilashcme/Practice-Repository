# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("electronic-card-transactions-april-2021-csv-tables-lower-level.csv")
print(df1)
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0       ECTM.S1AG1210  2007.01       887.3        NaN      F  Dollars
# 1       ECTM.S1AG1210  2007.02       843.9        NaN      F  Dollars
# 2       ECTM.S1AG1210  2007.03       925.1        NaN      F  Dollars
# 3       ECTM.S1AG1210  2007.04       880.0        NaN      F  Dollars
# 4       ECTM.S1AG1210  2007.05       905.1        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 5453    ECTQ.S1SQQ112  2020.03         NaN          Y      C  Dollars
# 5454    ECTQ.S1SQQ112  2020.06         NaN          Y      C  Dollars
# 5455    ECTQ.S1SQQ112  2020.09         NaN          Y      C  Dollars
# 5456    ECTQ.S1SQQ112  2020.12         NaN          Y      C  Dollars
# 5457    ECTQ.S1SQQ112  2021.03         NaN          Y      C  Dollars
#
#       Magnitude                                        Subject  \
# ...

# %%
df1.describe()
# Out:
#             Period   Data_value  Magnitude  Series_title_3  Series_title_4  \
# count  5458.000000  2746.000000     5458.0             0.0             0.0
# mean   2013.777069   490.043081        6.0             NaN             NaN
# std       4.109844   692.113397        0.0             NaN             NaN
# min    2007.010000    -1.400000        6.0             NaN             NaN
# 25%    2010.090000   136.700000        6.0             NaN             NaN
# 50%    2014.030000   233.050000        6.0             NaN             NaN
# 75%    2017.100000   525.425000        6.0             NaN             NaN
# max    2021.040000  5922.900000        6.0             NaN             NaN
#
#        Series_title_5
# count             0.0
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %%
df2 = pd.read_csv("electronic-card-transactions-april-2021-csv-tables-lower-level.csv",header = None)
print(df2)
# Out:
#                     0        1           2           3       4        5   \
# 0     Series_reference   Period  Data_value  Suppressed  STATUS    UNITS
# 1        ECTM.S1AG1210  2007.01       887.3         NaN       F  Dollars
# 2        ECTM.S1AG1210  2007.02       843.9         NaN       F  Dollars
# 3        ECTM.S1AG1210  2007.03       925.1         NaN       F  Dollars
# 4        ECTM.S1AG1210  2007.04         880         NaN       F  Dollars
# ...                ...      ...         ...         ...     ...      ...
# 5454     ECTQ.S1SQQ112  2020.03         NaN           Y       C  Dollars
# 5455     ECTQ.S1SQQ112  2020.06         NaN           Y       C  Dollars
# 5456     ECTQ.S1SQQ112  2020.09         NaN           Y       C  Dollars
# 5457     ECTQ.S1SQQ112  2020.12         NaN           Y       C  Dollars
# 5458     ECTQ.S1SQQ112  2021.03         NaN           Y       C  Dollars
#
#              6                                              7   \
# ...

# %%
## Read Table Function
df3 = pd.read_csv("electronic-card-transactions-april-2021-csv-tables-lower-level.csv",sep =',',header = None)
print(df3)
# Out:
#                     0        1           2           3       4        5   \
# 0     Series_reference   Period  Data_value  Suppressed  STATUS    UNITS
# 1        ECTM.S1AG1210  2007.01       887.3         NaN       F  Dollars
# 2        ECTM.S1AG1210  2007.02       843.9         NaN       F  Dollars
# 3        ECTM.S1AG1210  2007.03       925.1         NaN       F  Dollars
# 4        ECTM.S1AG1210  2007.04         880         NaN       F  Dollars
# ...                ...      ...         ...         ...     ...      ...
# 5454     ECTQ.S1SQQ112  2020.03         NaN           Y       C  Dollars
# 5455     ECTQ.S1SQQ112  2020.06         NaN           Y       C  Dollars
# 5456     ECTQ.S1SQQ112  2020.09         NaN           Y       C  Dollars
# 5457     ECTQ.S1SQQ112  2020.12         NaN           Y       C  Dollars
# 5458     ECTQ.S1SQQ112  2021.03         NaN           Y       C  Dollars
#
#              6                                              7   \
# ...

# %%
df4 = pd.read_csv("electronic-card-transactions-april-2021-csv-tables-lower-level.csv",nrows = 3 ,header = None)
print(df4)
# Out:
#                  0        1           2           3       4        5   \
# 0  Series_reference   Period  Data_value  Suppressed  STATUS    UNITS
# 1     ECTM.S1AG1210  2007.01       887.3         NaN       F  Dollars
# 2     ECTM.S1AG1210  2007.02       843.9         NaN       F  Dollars
#
#           6                                              7   \
# 0  Magnitude                                        Subject
# 1          6  Electronic Card Transactions (ANZSIC06) - ECT
# 2          6  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                   8               9   \
# 0                                              Group  Series_title_1
# 1  Private - Values - Electronic card transaction...          Actual
# 2  Private - Values - Electronic card transaction...          Actual
#
#                                10              11              12  \
# 0                  Series_title_2  Series_title_3  Series_title_4
# ...

# %%
# Dumping a dataframe to a CSV File
df3.to_csv('output.csv', columns = [0,1,2])

# %%
# Import Datas from Pandas
! pip install xlrd

# %%
! pip install openpyxl

# %%
excelfile = pd.ExcelFile('PGP required data.xlsx')
df = excelfile.parse('PGP DETAILS')

# %%
df
# Out:
#    Partner & Location  LOB Advisor OLMS ID                     Advisor name  \
# 0             Chennai  DTH        A1RH293A                         Lakchana
# 1             Chennai  DTH        A1USBUJN      Francis Jeraldina Sowmiya J
# 2             Chennai  DTH        A17DO6OS            Narmadha Ganaprakasam
# 3             Chennai  DTH        A1RBWNW4                         Nandhini
# 4             Chennai  DTH        A1YWW7CT                    Janani Mahesh
# 5             Chennai  DTH        A1MR0H99                   Divya Bharathi
# 6             Chennai  DTH        A1DYNKJA                        Vishali.V
# 7             Chennai  DTH        A1Q25BYC             Sunil Raj Subbarayan
# 8             Chennai  DTH        A1C5N864                      T.Raj Kumar
# 9             Chennai  DTH        A1ZBOFL3        A.Syed Mohammed Abbubakar
# 10            Chennai  DTH        A1001K7G                   R. Karthikeyan
# ...
